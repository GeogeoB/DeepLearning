# %% [markdown]
# # Chargement des données :
#
# Pour le projet **DeepLearning**, On classifie des affiches de films associées aux 9 labels suivants : **crime**, **documentary**, **family**, **history**, **horror**, **romance**, **science-fiction**, **war**, **western**.
#
# Les images sont dans le dossier **bdd** répartit en 3 dossiers: *train*, *validation* et *test*. Chacun de ces dossiers comporte un sous-dossier par classe, qui contient les images correspondantes. L'arborescence est disponible sur le [github du projet](https://github.com/GeogeoB/DeepLearning).
#
# Nous pouvons donc faire **git clone** pour récupérer le projet et la base de données.

# %%
# !git clone https://github.com/GeogeoB/DeepLearning
path = "./DeepLearning/bdd/"

# !pip install -q -U albumentations
# Out:
# fatal: destination path 'DeepLearning' already exists and is not an empty directory.

# %%
# !pip install focal_loss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: focal_loss in /usr/local/lib/python3.10/dist-packages (0.0.7)
# Requirement already satisfied: tensorflow>=2.2 in /usr/local/lib/python3.10/dist-packages (from focal_loss) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2->focal_loss) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2->focal_loss) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.2->focal_loss) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.2->focal_loss) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.2->focal_loss) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# ## Chargement des données

# %% [markdown]
# Fonction pour charger les images dans une matrice X et les classes associées dans une matrice y.

# %%
import os
import shutil

import numpy as np
import PIL
from PIL import Image
import os, sys
from scipy.io import loadmat


def load_data(data_path, classes, dataset, image_size=(64,64), max_par_categorie=10000):
    image_sizeY = image_size[0]
    image_sizeX = image_size[1]
  
    num_images = 0
    for i in range(len(classes)):
        dirs = sorted(os.listdir(data_path + dataset + '/' + classes[i]))
        #num_images += len(dirs)
        num_images += min(max_par_categorie,len(dirs))
                                
    x = np.zeros((num_images, image_sizeY, image_sizeX, 3))
    y = np.zeros((num_images, ), dtype=np.uint8)
    
    current_index = 0
    
    # Parcours des différents répertoires pour collecter les images
    for idx_class in range(len(classes)):
        dirs = sorted(os.listdir(data_path + dataset + '/' + classes[idx_class]))
        #num_images += len(dirs)
        num_images += max_par_categorie
    
        # Chargement des images,
        #for idx_img in range(len(dirs)):
        for idx_img in range(min(max_par_categorie,len(dirs))):
            item = dirs[idx_img]
            if os.path.isfile(data_path + dataset + '/' + classes[idx_class] + '/' + item):
                # Ouverture de l'image
                img = Image.open(data_path + dataset + '/' + classes[idx_class] + '/' + item)
                # Conversion de l'image en RGB
                img = img.convert('RGB')
                # Redimensionnement de l'image et écriture dans la variable de retour x 
                img = img.resize((image_sizeX,image_sizeY))
                x[current_index] = np.asarray(img)/255.0
                # Écriture du label associé dans la variable de retour y
                y[current_index] = idx_class
                current_index += 1
                
    return x, y

# %% [markdown]
# Création des 3 matrices (X,y) associées aux 3 groupes *train*, *eval* et *test*.

# %%
LABELS = ['crime', 'documentary', 'family', 'history', 'horror', 'romance', 'science-fiction', 'war', 'western']
NCLASS = len(LABELS)
IMAGE_SIZE = (345,230) # 345 pixel de haut, 230 de large
IMAGE_SIZE = (172, 115)

x_train, y_train = load_data(path, LABELS, dataset='Apprentissage', image_size=IMAGE_SIZE)
print("Taille X_train:", x_train.shape, "Taille y_train:", y_train.shape)

x_val, y_val = load_data(path, LABELS, dataset='Evaluation', image_size=IMAGE_SIZE)
print("Taille X_val:  ", x_val.shape, " Taille y_val:  ", y_val.shape)

x_test, y_test = load_data(path, LABELS, dataset='Test', image_size=IMAGE_SIZE)
print("Taille X_test: ", x_test.shape, " Taille y_test: ", y_test.shape)
# Out:
# Taille X_train: (2207, 172, 115, 3) Taille y_train: (2207,)
# Taille X_val:   (264, 172, 115, 3)  Taille y_val:   (264,)
# Taille X_test:  (264, 172, 115, 3)  Taille y_test:  (264,)

# %% [markdown]
# Mélanger les x et y pour éviter des problemes d'apprentissage

# %%
import random
ordre = list(range(x_train.shape[0]))
random.shuffle(ordre)
x_train = np.array([x_train[i,:,:,:] for i in ordre])
y_train = np.array([y_train[i] for i in ordre])

# %%
y_train
# Out:
# array([0, 5, 0, ..., 1, 0, 2], dtype=uint8)

# %% [markdown]
# Afficher une image pour chacun des genres:

# %%
import matplotlib.pyplot as plt
import random

# Dictionnaire pour associer chaque genre les indices dans x_train et y_train
genresIndices = {i: [] for i in range(NCLASS)}
for i, val in enumerate(y_train):
    genresIndices[val].append(i)

plt.figure(figsize=(12, 12))
random_indices = [random.choice(genresIndices[val]) for val in range(NCLASS)]
for i in range(0, NCLASS):
    plt.subplot(3, 3, i+1)
    # Enlever les axes
    plt.axis("off")
    image = x_train[random_indices[i]]
    plt.title(LABELS[y_train[random_indices[i]]])
    plt.imshow(image)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.utils import Sequence

class FILMSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.classes = LABELS
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0]) 
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))
    
    # Application de l'augmentation de données à chaque image du batch et aux
    # boîtes englobantes associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        batch_y = by
        
        # Pour chaque image du batch
        for i in range(len(bx)):
            img = bx[i].astype('float32')

            # Application de l'augmentation à l'image et aux masques
            transformed = self.augment(image=img.astype('float32'))
            batch_x[i] = transformed['image']
        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        batch_x = self.x[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)
        
        batch_y = np.array(batch_y)
        return np.array(batch_x), batch_y

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %% [markdown]
# cacul des poids de chaque classe pour la loss

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                  classes = np.unique(y_train),
                                  y = y_train)
#class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# array([0.46268344, 1.39330808, 1.40932312, 1.69118774, 1.50443081,
#        0.35385602, 1.97759857, 1.9936766 , 3.10407876])

# %%
def plot_training_analysis():
  acc = history.history['sparse_categorical_accuracy']
  val_acc = history.history['val_sparse_categorical_accuracy']
  acc_top = history.history['sparse_top_k_categorical_accuracy']
  val_acc_top = history.history['val_sparse_top_k_categorical_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'b', linestyle="--",label='Training acc')
  plt.plot(epochs, val_acc, 'g', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, acc_top, 'b', linestyle="--",label='Training acc top 3')
  plt.plot(epochs, val_acc_top, 'g', label='Validation acc top 3')
  plt.title('Training and validation accuracy top 3')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
  plt.plot(epochs, val_loss,'g', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# Data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from albumentations import (Compose, RandomBrightnessContrast, HorizontalFlip, ImageCompression, Sharpen, GaussNoise)
import albumentations as A


transforms = Compose([
    HorizontalFlip(),
    RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    Sharpen(),
    GaussNoise(var_limit=(0.0, 0.005))
    ],)

# create dataset
from imblearn.over_sampling import RandomOverSampler
su = RandomOverSampler(random_state=42)
x_train_reshape = x_train.reshape((x_train.shape[0], x_train.shape[1] * x_train.shape[2] * x_train.shape[3]))
x_su, y_su = su.fit_resample(x_train_reshape, y_train)
x_su = x_su.reshape((x_su.shape[0], x_train.shape[1], x_train.shape[2], x_train.shape[3]))
train_gen = FILMSequence(x_train, y_train, 32, augmentations=transforms)

# %%
print(x_su.shape, y_su.shape)
# Out:
# (6237, 172, 115, 3) (6237,)

# %%
plt.imshow(train_gen[10][0][0])

# %% [markdown]
# ## Entrainement

# %%
from keras.api._v2.keras import regularizers
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras import optimizers

loss = SparseCategoricalFocalLoss(gamma=0, class_weight=class_weights**0.8)
#train_generator = batch_generator(x_train, y_train, batch_size = 64)

from tensorflow.keras.regularizers import L2
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights='imagenet', # On utilise les poids du réseau déjà pré-entrainé sur la base de données ImageNet
                  include_top=False, # On ne conserve pas la partie Dense du réseau originel
                  input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

conv_base.trainable = False
print(conv_base.summary())

model = Sequential()
model.add(conv_base)
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=L2(0.03)))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=L2(0.03)))
model.add(Dropout(0.5))
model.add(Dense(NCLASS, 'softmax'))   # Couche de sortie


print(model.summary())

model.compile(loss=loss,
              optimizer=optimizers.Adam(learning_rate=3e-4),
              metrics=['sparse_categorical_accuracy', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3)])
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 172, 115, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 172, 115, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 172, 115, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 86, 57, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 86, 57, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 86, 57, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 43, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 43, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 43, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 43, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 21, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 21, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 21, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 21, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 10, 7, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 10, 7, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 10, 7, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 10, 7, 512)        2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 3, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 5, 3, 512)         14714688
#
#  flatten_8 (Flatten)         (None, 7680)              0
#
#  dense_24 (Dense)            (None, 512)               3932672
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 128)               65664
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 9)                 1161
#
# =================================================================
# Total params: 18,714,185
# Trainable params: 3,999,497
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_saver = ModelCheckpoint('tmp/best_weights', monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')

history = model.fit(train_gen, 
                    validation_data=(x_val, y_val),
                    epochs=30,
                    )
''' history = model.fit(x_train, y_train, batch_size=64, 
                    validation_data=(x_val, y_val),
                    epochs=20,
                    ) '''
# Out:
# Epoch 1/30
# 69/69 [==============================] - 7s 79ms/step - loss: 22.5401 - sparse_categorical_accuracy: 0.1359 - sparse_top_k_categorical_accuracy: 0.4024 - val_loss: 13.1988 - val_sparse_categorical_accuracy: 0.1856 - val_sparse_top_k_categorical_accuracy: 0.5000
# Epoch 2/30
# 69/69 [==============================] - 5s 77ms/step - loss: 9.8252 - sparse_categorical_accuracy: 0.1767 - sparse_top_k_categorical_accuracy: 0.4214 - val_loss: 7.4780 - val_sparse_categorical_accuracy: 0.2273 - val_sparse_top_k_categorical_accuracy: 0.4470
# Epoch 3/30
# 69/69 [==============================] - 5s 76ms/step - loss: 6.2233 - sparse_categorical_accuracy: 0.1785 - sparse_top_k_categorical_accuracy: 0.4531 - val_loss: 5.2816 - val_sparse_categorical_accuracy: 0.2273 - val_sparse_top_k_categorical_accuracy: 0.5530
# Epoch 4/30
# 69/69 [==============================] - 5s 77ms/step - loss: 4.6511 - sparse_categorical_accuracy: 0.1808 - sparse_top_k_categorical_accuracy: 0.4631 - val_loss: 4.1670 - val_sparse_categorical_accuracy: 0.3106 - val_sparse_top_k_categorical_accuracy: 0.5720
# Epoch 5/30
# 69/69 [==============================] - 7s 103ms/step - loss: 3.7753 - sparse_categorical_accuracy: 0.2107 - sparse_top_k_categorical_accuracy: 0.5007 - val_loss: 3.5057 - val_sparse_categorical_accuracy: 0.2917 - val_sparse_top_k_categorical_accuracy: 0.6553
# Epoch 6/30
# 69/69 [==============================] - 6s 84ms/step - loss: 3.2673 - sparse_categorical_accuracy: 0.2216 - sparse_top_k_categorical_accuracy: 0.5211 - val_loss: 3.1000 - val_sparse_categorical_accuracy: 0.3258 - val_sparse_top_k_categorical_accuracy: 0.6818
# Epoch 7/30
# 69/69 [==============================] - 5s 77ms/step - loss: 2.9439 - sparse_categorical_accuracy: 0.2315 - sparse_top_k_categorical_accuracy: 0.5523 - val_loss: 2.8727 - val_sparse_categorical_accuracy: 0.2689 - val_sparse_top_k_categorical_accuracy: 0.5758
# Epoch 8/30
# 69/69 [==============================] - 5s 79ms/step - loss: 2.7402 - sparse_categorical_accuracy: 0.2121 - sparse_top_k_categorical_accuracy: 0.5537 - val_loss: 2.6671 - val_sparse_categorical_accuracy: 0.3523 - val_sparse_top_k_categorical_accuracy: 0.6818
# Epoch 9/30
# 69/69 [==============================] - 5s 75ms/step - loss: 2.6103 - sparse_categorical_accuracy: 0.2134 - sparse_top_k_categorical_accuracy: 0.5387 - val_loss: 2.5842 - val_sparse_categorical_accuracy: 0.2576 - val_sparse_top_k_categorical_accuracy: 0.6061
# Epoch 10/30
# 69/69 [==============================] - 5s 78ms/step - loss: 2.4847 - sparse_categorical_accuracy: 0.2247 - sparse_top_k_categorical_accuracy: 0.5686 - val_loss: 2.4822 - val_sparse_categorical_accuracy: 0.2879 - val_sparse_top_k_categorical_accuracy: 0.6098
# Epoch 11/30
# 69/69 [==============================] - 5s 77ms/step - loss: 2.4129 - sparse_categorical_accuracy: 0.2225 - sparse_top_k_categorical_accuracy: 0.5641 - val_loss: 2.4087 - val_sparse_categorical_accuracy: 0.3447 - val_sparse_top_k_categorical_accuracy: 0.6818
# Epoch 12/30
# 69/69 [==============================] - 5s 73ms/step - loss: 2.3488 - sparse_categorical_accuracy: 0.2256 - sparse_top_k_categorical_accuracy: 0.5646 - val_loss: 2.3906 - val_sparse_categorical_accuracy: 0.2197 - val_sparse_top_k_categorical_accuracy: 0.6023
# Epoch 13/30
# 69/69 [==============================] - 5s 78ms/step - loss: 2.2960 - sparse_categorical_accuracy: 0.2161 - sparse_top_k_categorical_accuracy: 0.5655 - val_loss: 2.3091 - val_sparse_categorical_accuracy: 0.3598 - val_sparse_top_k_categorical_accuracy: 0.6742
# Epoch 14/30
# 69/69 [==============================] - 5s 77ms/step - loss: 2.2664 - sparse_categorical_accuracy: 0.2179 - sparse_top_k_categorical_accuracy: 0.5655 - val_loss: 2.2877 - val_sparse_categorical_accuracy: 0.2992 - val_sparse_top_k_categorical_accuracy: 0.6364
# Epoch 15/30
# 69/69 [==============================] - 5s 79ms/step - loss: 2.2238 - sparse_categorical_accuracy: 0.2655 - sparse_top_k_categorical_accuracy: 0.5927 - val_loss: 2.2649 - val_sparse_categorical_accuracy: 0.2727 - val_sparse_top_k_categorical_accuracy: 0.6098
# Epoch 16/30
# 69/69 [==============================] - 5s 73ms/step - loss: 2.2022 - sparse_categorical_accuracy: 0.2293 - sparse_top_k_categorical_accuracy: 0.5696 - val_loss: 2.2592 - val_sparse_categorical_accuracy: 0.2955 - val_sparse_top_k_categorical_accuracy: 0.5909
# Epoch 17/30
# 69/69 [==============================] - 5s 75ms/step - loss: 2.1754 - sparse_categorical_accuracy: 0.2429 - sparse_top_k_categorical_accuracy: 0.5931 - val_loss: 2.1989 - val_sparse_categorical_accuracy: 0.3068 - val_sparse_top_k_categorical_accuracy: 0.6667
# Epoch 18/30
# 69/69 [==============================] - 5s 76ms/step - loss: 2.1559 - sparse_categorical_accuracy: 0.2288 - sparse_top_k_categorical_accuracy: 0.5836 - val_loss: 2.2358 - val_sparse_categorical_accuracy: 0.2273 - val_sparse_top_k_categorical_accuracy: 0.6061
# Epoch 19/30
# 69/69 [==============================] - 5s 74ms/step - loss: 2.1361 - sparse_categorical_accuracy: 0.2356 - sparse_top_k_categorical_accuracy: 0.5859 - val_loss: 2.2113 - val_sparse_categorical_accuracy: 0.2955 - val_sparse_top_k_categorical_accuracy: 0.6098
# Epoch 20/30
# 69/69 [==============================] - 5s 74ms/step - loss: 2.1345 - sparse_categorical_accuracy: 0.2537 - sparse_top_k_categorical_accuracy: 0.6076 - val_loss: 2.2061 - val_sparse_categorical_accuracy: 0.3182 - val_sparse_top_k_categorical_accuracy: 0.6250
# Epoch 21/30
# 69/69 [==============================] - 5s 76ms/step - loss: 2.0999 - sparse_categorical_accuracy: 0.2669 - sparse_top_k_categorical_accuracy: 0.6271 - val_loss: 2.2103 - val_sparse_categorical_accuracy: 0.2917 - val_sparse_top_k_categorical_accuracy: 0.6326
# Epoch 22/30
# 69/69 [==============================] - 5s 77ms/step - loss: 2.0972 - sparse_categorical_accuracy: 0.2619 - sparse_top_k_categorical_accuracy: 0.6149 - val_loss: 2.2262 - val_sparse_categorical_accuracy: 0.2121 - val_sparse_top_k_categorical_accuracy: 0.5606
# Epoch 23/30
# 69/69 [==============================] - 6s 84ms/step - loss: 2.0940 - sparse_categorical_accuracy: 0.2460 - sparse_top_k_categorical_accuracy: 0.6203 - val_loss: 2.1907 - val_sparse_categorical_accuracy: 0.2614 - val_sparse_top_k_categorical_accuracy: 0.6023
# Epoch 24/30
# 69/69 [==============================] - 5s 75ms/step - loss: 2.0906 - sparse_categorical_accuracy: 0.2501 - sparse_top_k_categorical_accuracy: 0.6176 - val_loss: 2.2183 - val_sparse_categorical_accuracy: 0.3106 - val_sparse_top_k_categorical_accuracy: 0.6402
# Epoch 25/30
# 69/69 [==============================] - 6s 82ms/step - loss: 2.0831 - sparse_categorical_accuracy: 0.2569 - sparse_top_k_categorical_accuracy: 0.6266 - val_loss: 2.2023 - val_sparse_categorical_accuracy: 0.3068 - val_sparse_top_k_categorical_accuracy: 0.6212
# Epoch 26/30
# 69/69 [==============================] - 6s 80ms/step - loss: 2.0645 - sparse_categorical_accuracy: 0.2660 - sparse_top_k_categorical_accuracy: 0.6312 - val_loss: 2.1818 - val_sparse_categorical_accuracy: 0.2803 - val_sparse_top_k_categorical_accuracy: 0.6326
# Epoch 27/30
# 69/69 [==============================] - 5s 75ms/step - loss: 2.0716 - sparse_categorical_accuracy: 0.2592 - sparse_top_k_categorical_accuracy: 0.6339 - val_loss: 2.2179 - val_sparse_categorical_accuracy: 0.2765 - val_sparse_top_k_categorical_accuracy: 0.6061
# Epoch 28/30
# 69/69 [==============================] - 5s 77ms/step - loss: 2.0704 - sparse_categorical_accuracy: 0.2456 - sparse_top_k_categorical_accuracy: 0.6271 - val_loss: 2.2371 - val_sparse_categorical_accuracy: 0.2879 - val_sparse_top_k_categorical_accuracy: 0.6136
# Epoch 29/30
# 69/69 [==============================] - 5s 74ms/step - loss: 2.0678 - sparse_categorical_accuracy: 0.2764 - sparse_top_k_categorical_accuracy: 0.6479 - val_loss: 2.1941 - val_sparse_categorical_accuracy: 0.3106 - val_sparse_top_k_categorical_accuracy: 0.6515
# Epoch 30/30
# 69/69 [==============================] - 6s 81ms/step - loss: 2.0773 - sparse_categorical_accuracy: 0.2655 - sparse_top_k_categorical_accuracy: 0.6271 - val_loss: 2.2325 - val_sparse_categorical_accuracy: 0.2500 - val_sparse_top_k_categorical_accuracy: 0.6174
# ' history = model.fit(x_train, y_train, batch_size=64, \n                    validation_data=(x_val, y_val),\n                    epochs=20,\n                    ) '

# %%
plot_training_analysis()

# %% [markdown]
# ## Fine Tuning

# %%
conv_base.trainable = True
model.compile(loss=loss,
              optimizer=optimizers.Adam(learning_rate=1e-5),
              metrics=['sparse_categorical_accuracy', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3)])
history = model.fit(train_gen, 
                    validation_data=(x_val, y_val),
                    epochs=5,
                    callbacks = [model_saver],
                    )
# Out:
# Epoch 1/5
# 69/69 [==============================] - ETA: 0s - loss: 2.0329 - sparse_categorical_accuracy: 0.2719 - sparse_top_k_categorical_accuracy: 0.6457
# Epoch 1: val_loss improved from inf to 2.23024, saving model to tmp/best_weights
# 69/69 [==============================] - 20s 199ms/step - loss: 2.0329 - sparse_categorical_accuracy: 0.2719 - sparse_top_k_categorical_accuracy: 0.6457 - val_loss: 2.2302 - val_sparse_categorical_accuracy: 0.2235 - val_sparse_top_k_categorical_accuracy: 0.5114
# Epoch 2/5
# 69/69 [==============================] - ETA: 0s - loss: 1.9385 - sparse_categorical_accuracy: 0.3072 - sparse_top_k_categorical_accuracy: 0.6783
# Epoch 2: val_loss improved from 2.23024 to 2.19284, saving model to tmp/best_weights
# 69/69 [==============================] - 14s 197ms/step - loss: 1.9385 - sparse_categorical_accuracy: 0.3072 - sparse_top_k_categorical_accuracy: 0.6783 - val_loss: 2.1928 - val_sparse_categorical_accuracy: 0.3144 - val_sparse_top_k_categorical_accuracy: 0.6477
# Epoch 3/5
# 69/69 [==============================] - ETA: 0s - loss: 1.8727 - sparse_categorical_accuracy: 0.3203 - sparse_top_k_categorical_accuracy: 0.7014
# Epoch 3: val_loss improved from 2.19284 to 2.18166, saving model to tmp/best_weights
# 69/69 [==============================] - 14s 198ms/step - loss: 1.8727 - sparse_categorical_accuracy: 0.3203 - sparse_top_k_categorical_accuracy: 0.7014 - val_loss: 2.1817 - val_sparse_categorical_accuracy: 0.2803 - val_sparse_top_k_categorical_accuracy: 0.6061
# Epoch 4/5
# 69/69 [==============================] - ETA: 0s - loss: 1.7940 - sparse_categorical_accuracy: 0.3484 - sparse_top_k_categorical_accuracy: 0.7186
# Epoch 4: val_loss did not improve from 2.18166
# 69/69 [==============================] - 13s 190ms/step - loss: 1.7940 - sparse_categorical_accuracy: 0.3484 - sparse_top_k_categorical_accuracy: 0.7186 - val_loss: 2.2042 - val_sparse_categorical_accuracy: 0.3220 - val_sparse_top_k_categorical_accuracy: 0.6515
# Epoch 5/5
# 69/69 [==============================] - ETA: 0s - loss: 1.7531 - sparse_categorical_accuracy: 0.3457 - sparse_top_k_categorical_accuracy: 0.7191
# Epoch 5: val_loss did not improve from 2.18166
# 69/69 [==============================] - 13s 187ms/step - loss: 1.7531 - sparse_categorical_accuracy: 0.3457 - sparse_top_k_categorical_accuracy: 0.7191 - val_loss: 2.2010 - val_sparse_categorical_accuracy: 0.2841 - val_sparse_top_k_categorical_accuracy: 0.5833

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_prediction = model.predict(x_train)
y_prediction = np.argmax(y_prediction, axis = 1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_train, y_prediction, normalize='true').round(2)
sns.heatmap(result, annot=True)
# Out:
# 69/69 [==============================] - 4s 53ms/step
# <Axes: >

# %%
y_prediction = model.predict(x_val)
y_prediction = np.argmax(y_prediction, axis = 1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_val, y_prediction, normalize='true').round(2)
sns.heatmap(result, annot=True)
# Out:
# 9/9 [==============================] - 0s 52ms/step
# <Axes: >

# %%
print(f'Accuracy = {sum(y_prediction == y_val)/len(y_val) * 100}%')
# Out:
# Accuracy = 28.40909090909091%

# %% [markdown]
# ## Test

# %%
y_prediction = model.predict(x_test)
y_prediction = np.argmax(y_prediction, axis = 1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction, normalize='true').round(2)
sns.heatmap(result, annot=True)
# Out:
# 9/9 [==============================] - 0s 52ms/step
# <Axes: >

# %%
print(f'Accuracy = {sum(y_prediction == y_test)/len(y_test) * 100}%')
# Out:
# Accuracy = 32.196969696969695%

# %% [markdown]
# ## Quelques résultats

# %%
incorrect_indices = np.nonzero(y_prediction != y_test)[0]
bonnes_indices = np.nonzero(y_prediction == y_test)[0]

# %%
item = incorrect_indices[73]

plt.imshow(x_test[item])
plt.show()
print("vrai : " + LABELS[y_test[item]] + ", ", "prédiction : " + LABELS[y_prediction[item]])
# Out:
# vrai : history,  prédiction : romance

# %%
item = bonnes_indices[84]

plt.imshow(x_test[item])
plt.show()
print("vrai : " + LABELS[y_test[item]] + ", ", "prédiction : " + LABELS[y_prediction[item]])
# Out:
# vrai : western,  prédiction : western
